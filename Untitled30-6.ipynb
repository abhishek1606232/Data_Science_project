# %% [markdown]
# importing libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd

dataset_path = "/content/drive/MyDrive/kaggle_3m"

def load_brain_mri_data(dataset_path, num_folders=40, img_size=(128, 128)):
    """
    Load and preprocess brain MRI data in one function
    """
    images = []
    masks = []
    filenames = []

    print(f"Loading first {num_folders} folders...")
    patient_folders = sorted(os.listdir(dataset_path))[:num_folders]

    for i, folder in enumerate(patient_folders):
        folder_path = os.path.join(dataset_path, folder)

        if os.path.isdir(folder_path):
            files = sorted(os.listdir(folder_path))
            image_files = [f for f in files if not f.endswith('_mask.tif') and f.endswith('.tif')]

            for img_file in image_files:
                mask_file = img_file.replace('.tif', '_mask.tif')

                if mask_file in files:
                    # Load and preprocess image
                    img_path = os.path.join(folder_path, img_file)
                    image = cv2.imread(img_path)
                    image = cv2.resize(image, img_size)
                    image = image.astype('float32') / 255.0

                    # Load and preprocess mask
                    mask_path = os.path.join(folder_path, mask_file)
                    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                    mask = cv2.resize(mask, img_size)
                    mask = (mask > 128).astype('float32')
                    mask = np.expand_dims(mask, axis=-1)

                    images.append(image)
                    masks.append(mask)
                    filenames.append(f"{folder}/{img_file}")

        if (i + 1) % 10 == 0:
            print(f"Processed {i + 1}/{num_folders} folders")

    return np.array(images), np.array(masks), filenames

def split_dataset(images, masks, filenames, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    """
    Split dataset into train, validation, and test sets
    """
    # First split: separate train+val from test
    X_temp, X_test, y_temp, y_test, names_temp, names_test = train_test_split(
        images, masks, filenames, test_size=test_ratio, random_state=42
    )

    # Second split: separate train from val
    val_size = val_ratio / (train_ratio + val_ratio)
    X_train, X_val, y_train, y_val, names_train, names_val = train_test_split(
        X_temp, y_temp, names_temp, test_size=val_size, random_state=42
    )

    print(f"Dataset split:")
    print(f"Training: {len(X_train)} samples")
    print(f"Validation: {len(X_val)} samples")
    print(f"Test: {len(X_test)} samples")

    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

# Load and preprocess data
print("Loading and preprocessing brain MRI data...")
images, masks, filenames = load_brain_mri_data(dataset_path, num_folders=40)

# Split the dataset
(X_train, y_train), (X_val, y_val), (X_test, y_test) = split_dataset(images, masks, filenames)

print(f"\nFinal dataset shapes:")
print(f"X_train: {X_train.shape}, y_train: {y_train.shape}")
print(f"X_val: {X_val.shape}, y_val: {y_val.shape}")
print(f"X_test: {X_test.shape}, y_test: {y_test.shape}")
# Out:
# Loading and preprocessing brain MRI data...
# Loading first 40 folders...
# Processed 10/40 folders
# Processed 20/40 folders
# Processed 30/40 folders
# Processed 40/40 folders
# Dataset split:
# Training: 1000 samples
# Validation: 215 samples
# Test: 215 samples
#
# Final dataset shapes:
# X_train: (1000, 128, 128, 3), y_train: (1000, 128, 128, 1)
# X_val: (215, 128, 128, 3), y_val: (215, 128, 128, 1)
# X_test: (215, 128, 128, 3), y_test: (215, 128, 128, 1)

# %%
# Custom metrics for segmentation
class SegmentationMetrics:
    @staticmethod
    def dice_coefficient(y_true, y_pred, smooth=1e-6):
        y_true_f = tf.keras.backend.flatten(y_true)
        y_pred_f = tf.keras.backend.flatten(y_pred)
        intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
        return (2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth)

    @staticmethod
    def iou_score(y_true, y_pred, smooth=1e-6):
        y_true_f = tf.keras.backend.flatten(y_true)
        y_pred_f = tf.keras.backend.flatten(y_pred)
        intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
        union = tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) - intersection
        return (intersection + smooth) / (union + smooth)

def visualize_sample_data(X, y, num_samples=5):
    """
    Visualize sample images and masks
    """
    fig, axes = plt.subplots(num_samples, 3, figsize=(15, 5*num_samples))

    indices = np.random.choice(len(X), num_samples, replace=False)

    for i, idx in enumerate(indices):
        # Original image
        axes[i, 0].imshow(X[idx])
        axes[i, 0].set_title('MRI Image')
        axes[i, 0].axis('off')

        # Ground truth mask
        axes[i, 1].imshow(y[idx].squeeze(), cmap='gray')
        axes[i, 1].set_title('Ground Truth Mask')
        axes[i, 1].axis('off')

        # Overlay
        axes[i, 2].imshow(X[idx])
        axes[i, 2].imshow(y[idx].squeeze(), alpha=0.5, cmap='jet')
        axes[i, 2].set_title('Overlay')
        axes[i, 2].axis('off')

    plt.tight_layout()
    plt.show()

# Visualize some samples
print("Visualizing sample data...")
visualize_sample_data(X_train, y_train, num_samples=3)
# Out:
# Visualizing sample data...

# %%
def build_unet_model(input_shape=(128, 128, 3)):
    """
    Enhanced U-Net model with batch normalization
    """
    inputs = keras.Input(input_shape)

    # Encoder
    # Block 1
    c1 = layers.Conv2D(64, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, 3, activation='relu', padding='same')(c1)
    c1 = layers.BatchNormalization()(c1)
    p1 = layers.MaxPooling2D(2)(c1)

    # Block 2
    c2 = layers.Conv2D(128, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, 3, activation='relu', padding='same')(c2)
    c2 = layers.BatchNormalization()(c2)
    p2 = layers.MaxPooling2D(2)(c2)

    # Block 3
    c3 = layers.Conv2D(256, 3, activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, 3, activation='relu', padding='same')(c3)
    c3 = layers.BatchNormalization()(c3)
    p3 = layers.MaxPooling2D(2)(c3)

    # Bridge
    c4 = layers.Conv2D(512, 3, activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(512, 3, activation='relu', padding='same')(c4)
    c4 = layers.BatchNormalization()(c4)

    # Decoder
    # Block 1
    u5 = layers.Conv2DTranspose(256, 2, strides=2, padding='same')(c4)
    u5 = layers.concatenate([u5, c3])
    c5 = layers.Conv2D(256, 3, activation='relu', padding='same')(u5)
    c5 = layers.Conv2D(256, 3, activation='relu', padding='same')(c5)
    c5 = layers.BatchNormalization()(c5)

    # Block 2
    u6 = layers.Conv2DTranspose(128, 2, strides=2, padding='same')(c5)
    u6 = layers.concatenate([u6, c2])
    c6 = layers.Conv2D(128, 3, activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(128, 3, activation='relu', padding='same')(c6)
    c6 = layers.BatchNormalization()(c6)

    # Block 3
    u7 = layers.Conv2DTranspose(64, 2, strides=2, padding='same')(c6)
    u7 = layers.concatenate([u7, c1])
    c7 = layers.Conv2D(64, 3, activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(64, 3, activation='relu', padding='same')(c7)
    c7 = layers.BatchNormalization()(c7)

    # Output
    outputs = layers.Conv2D(1, 1, activation='sigmoid')(c7)

    model = keras.Model(inputs, outputs, name='U-Net')
    return model

# Build U-Net
print("Building U-Net model...")
unet_model = build_unet_model()
unet_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy', SegmentationMetrics.dice_coefficient, SegmentationMetrics.iou_score]
)
unet_model.summary()
# Out:
# Building U-Net model...
# Model: "U-Net"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 128, 128,  │      1,792 │ input_layer_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_29[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
def residual_block(x, filters):
    """
    Residual block with two convolutions
    """
    shortcut = x

    # First convolution
    x = layers.Conv2D(filters, 3, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)

    # Second convolution
    x = layers.Conv2D(filters, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)

    # Adjust shortcut if needed
    if shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(filters, 1, padding='same')(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    # Add shortcut
    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)

    return x

def build_resunet(input_shape=(128, 128, 3)):
    """
    ResUNet with residual connections
    """
    inputs = keras.Input(input_shape)

    # Initial convolution
    x = layers.Conv2D(64, 3, padding='same', activation='relu')(inputs)
    x = layers.BatchNormalization()(x)

    # Encoder
    # Block 1
    res1 = residual_block(x, 64)
    pool1 = layers.MaxPooling2D(2)(res1)

    # Block 2
    res2 = residual_block(pool1, 128)
    pool2 = layers.MaxPooling2D(2)(res2)

    # Block 3
    res3 = residual_block(pool2, 256)
    pool3 = layers.MaxPooling2D(2)(res3)

    # Bridge
    bridge = residual_block(pool3, 512)

    # Decoder
    # Block 1
    up1 = layers.UpSampling2D(2)(bridge)
    up1 = layers.concatenate([up1, res3])
    dec1 = residual_block(up1, 256)

    # Block 2
    up2 = layers.UpSampling2D(2)(dec1)
    up2 = layers.concatenate([up2, res2])
    dec2 = residual_block(up2, 128)

    # Block 3
    up3 = layers.UpSampling2D(2)(dec2)
    up3 = layers.concatenate([up3, res1])
    dec3 = residual_block(up3, 64)

    # Output
    outputs = layers.Conv2D(1, 1, activation='sigmoid')(dec3)

    model = keras.Model(inputs, outputs, name='ResUNet')
    return model

# Build ResUNet
print("Building ResUNet model...")
resunet_model = build_resunet()
resunet_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy', SegmentationMetrics.dice_coefficient, SegmentationMetrics.iou_score]
)
resunet_model.summary()
# Out:
# Building ResUNet model...
# Model: "ResUNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_78 (Conv2D)  │ (None, 128, 128,  │      1,792 │ input_layer_5[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_78[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
def train_individual_model(model, model_name, X_train, y_train, X_val, y_val, epochs=25):
    """
    Train a single model and return history and results
    """
    print(f"\n{'='*60}")
    print(f"TRAINING {model_name.upper()}")
    print(f"{'='*60}")

    # Callbacks
    callbacks = [
        keras.callbacks.EarlyStopping(patience=8, restore_best_weights=True, verbose=1),
        keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=1e-7, verbose=1),
        keras.callbacks.ModelCheckpoint(f'best_{model_name.lower().replace("-", "_")}.h5',
                                      save_best_only=True, verbose=1)
    ]

    # Train model
    start_time = time.time()
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=16,
        callbacks=callbacks,
        verbose=1
    )
    training_time = time.time() - start_time

    # Evaluate
    print(f"\nEvaluating {model_name} on test set...")
    test_loss, test_accuracy, test_dice, test_iou = model.evaluate(X_test, y_test, verbose=0)

    print(f"\n📊 {model_name} Test Results:")
    print(f"   Test Loss: {test_loss:.4f}")
    print(f"   Test Accuracy: {test_accuracy:.4f}")
    print(f"   Dice Coefficient: {test_dice:.4f}")
    print(f"   IoU Score: {test_iou:.4f}")
    print(f"   Training Time: {training_time:.2f} seconds")

    # Visualize results
    plot_training_history(history, model_name)
    visualize_predictions(model, model_name, X_test, y_test)

    return model, history, {
        'loss': test_loss,
        'accuracy': test_accuracy,
        'dice': test_dice,
        'iou': test_iou,
        'training_time': training_time
    }

# %%
import time

# %%
unet_model, unet_history, unet_results = train_individual_model(
    unet_model, "U-Net", X_train, y_train, X_val, y_val, epochs=30
)
# Out:
# ...
# TRAINING U-NET
# ...
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.7846 - dice_coefficient: 0.0301 - iou_score: 0.0153 - loss: 0.6551
# Epoch 1: val_loss improved from inf to 0.32522, saving model to best_u_net.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 39s 351ms/step - accuracy: 0.7865 - dice_coefficient: 0.0301 - iou_score: 0.0154 - loss: 0.6535 - val_accuracy: 0.9890 - val_dice_coefficient: 0.0207 - val_iou_score: 0.0105 - val_loss: 0.3252 - learning_rate: 0.0010
# Epoch 2/30
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9816 - dice_coefficient: 0.0421 - iou_score: 0.0217 - loss: 0.3529
# Epoch 2: val_loss improved from 0.32522 to 0.18064, saving model to best_u_net.h5
# ...

# %%
# 4. Train ResUNet
resunet_model, resunet_history, resunet_results = train_individual_model(
    resunet_model, "ResUNet", X_train, y_train, X_val, y_val, epochs=30
)
# Out:
# ...
# TRAINING RESUNET
# ...
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9171 - dice_coefficient: 0.1453 - iou_score: 0.0848 - loss: 0.1702
# Epoch 1: val_loss improved from inf to 0.09078, saving model to best_resunet.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 46s 395ms/step - accuracy: 0.9180 - dice_coefficient: 0.1466 - iou_score: 0.0857 - loss: 0.1686 - val_accuracy: 0.9890 - val_dice_coefficient: 0.0191 - val_iou_score: 0.0096 - val_loss: 0.0908 - learning_rate: 0.0010
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9934 - dice_coefficient: 0.3815 - iou_score: 0.2418 - loss: 0.0253
# ...

# %%
def build_light_deeplabv3(input_shape=(128, 128, 3)):
    """
    Lightweight DeepLabV3+ implementation - FIXED
    """
    def aspp_module(x, filters):
        # Different dilation rates
        rate6 = layers.Conv2D(filters, 3, dilation_rate=6, padding='same', activation='relu')(x)
        rate12 = layers.Conv2D(filters, 3, dilation_rate=12, padding='same', activation='relu')(x)
        rate18 = layers.Conv2D(filters, 3, dilation_rate=18, padding='same', activation='relu')(x)

        # Global context - FIXED: use keepdims=True instead of separate reshape
        pool = layers.GlobalAveragePooling2D(keepdims=True)(x)  # This keeps (1, 1, filters) shape
        pool = layers.Conv2D(filters, 1, activation='relu')(pool)
        pool = layers.UpSampling2D(size=x.shape[1:3], interpolation='bilinear')(pool)

        # Concatenate all branches
        concatenated = layers.concatenate([rate6, rate12, rate18, pool])
        output = layers.Conv2D(filters, 1, activation='relu')(concatenated)

        return output

    inputs = keras.Input(input_shape)

    # Encoder
    # Initial convolution
    x = layers.Conv2D(32, 3, strides=2, padding='same', activation='relu')(inputs)  # 64x64
    x = layers.Conv2D(64, 3, padding='same', activation='relu')(x)  # 64x64
    low_level = x  # Save for skip connection

    # Middle flow
    x = layers.Conv2D(128, 3, strides=2, padding='same', activation='relu')(x)  # 32x32
    x = layers.Conv2D(128, 3, padding='same', activation='relu')(x)  # 32x32

    # ASPP module (input: 32x32)
    x = aspp_module(x, 64)  # Output: 32x32

    # Decoder
    # Upsample ASPP output (32x32 -> 64x64)
    x = layers.UpSampling2D(2, interpolation='bilinear')(x)

    # Process low-level features (64x64)
    low_level = layers.Conv2D(32, 1, activation='relu')(low_level)

    # Combine features (both 64x64 now)
    x = layers.concatenate([x, low_level])
    x = layers.Conv2D(128, 3, padding='same', activation='relu')(x)
    x = layers.Conv2D(128, 3, padding='same', activation='relu')(x)

    # Final upsampling to original size (64x64 -> 128x128)
    x = layers.UpSampling2D(2, interpolation='bilinear')(x)
    outputs = layers.Conv2D(1, 1, activation='sigmoid')(x)

    model = keras.Model(inputs, outputs, name='DeepLabV3-Light')
    return model

# Build DeepLabV3+
print("Building DeepLabV3+ model...")
deeplab_model = build_light_deeplabv3()
deeplab_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy', SegmentationMetrics.dice_coefficient, SegmentationMetrics.iou_score]
)
deeplab_model.summary()
# Out:
# Building DeepLabV3+ model...
# Model: "DeepLabV3-Light"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_10      │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_149 (Conv2D) │ (None, 64, 64,    │        896 │ input_layer_10[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_150 (Conv2D) │ (None, 64, 64,    │     18,496 │ conv2d_149[0][0]  │
# │                     │ 64)               │            │                   │
# ...

# %%
# 4. Train DeepLabV3+
deeplab_model, deeplab_history, deeplab_results = train_individual_model(
    deeplab_model, "DeepLabV3+", X_train, y_train, X_val, y_val, epochs=30
)
# Out:
# ...
# TRAINING DEEPLABV3+
# ...
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9199 - dice_coefficient: 0.0206 - iou_score: 0.0106 - loss: 0.2161
# Epoch 1: val_loss improved from inf to 0.02906, saving model to best_deeplabv3+.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 24s 201ms/step - accuracy: 0.9207 - dice_coefficient: 0.0210 - iou_score: 0.0108 - loss: 0.2143 - val_accuracy: 0.9890 - val_dice_coefficient: 0.2073 - val_iou_score: 0.1160 - val_loss: 0.0291 - learning_rate: 0.0010
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9906 - dice_coefficient: 0.2308 - iou_score: 0.1339 - loss: 0.0269
# ...
